# %%
import pandas as pd
import numpy as np

# %%
# reading the csv file

# %%
# first look at the dataset

# %% [markdown]
# # 1 make a pivot table

# %% [markdown]
# ##### .pivot() returns reshaped dataframe orhanized by given / columns values (pivot without aggregation)

# %%
# droPping null values

# %%
#making a pivot table
